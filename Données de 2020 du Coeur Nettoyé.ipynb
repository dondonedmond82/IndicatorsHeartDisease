# %%
import panel as pn
import numpy as np
import pandas as pd
import hvplot.pandas
import warnings
import datetime as dt
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart_2020_cleaned.csv")

# %%
df.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.isna().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
number_details = ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Sex',
                          aggfunc=sum)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_ed07d_row0_col0, #T_ed07d_row0_col1, #T_ed07d_row0_col2, #T_ed07d_row0_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ed07d_row1_col0, #T_ed07d_row1_col1, #T_ed07d_row1_col2, #T_ed07d_row1_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ed07d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed07d_level0_col0" class="col_heading level0 col0" >BMI</th>
#       <th id="T_ed07d_level0_col1" class="col_heading level0 col1" >MentalHealth</th>
#       <th id="T_ed07d_level0_col2" class="col_heading level0 col2" >PhysicalHealth</th>
#       <th id="T_ed07d_level0_col3" class="col_heading level0 col3" >SleepTime</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Sex',
                          aggfunc=max)

segment_hs_code_description = segment_hs_code_description.sort_values(by='BMI', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_ce26e_row0_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ce26e_row0_col1, #T_ce26e_row0_col2, #T_ce26e_row0_col3, #T_ce26e_row1_col0, #T_ce26e_row1_col1, #T_ce26e_row1_col2, #T_ce26e_row1_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ce26e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce26e_level0_col0" class="col_heading level0 col0" >BMI</th>
#       <th id="T_ce26e_level0_col1" class="col_heading level0 col1" >MentalHealth</th>
#       <th id="T_ce26e_level0_col2" class="col_heading level0 col2" >PhysicalHealth</th>
#       <th id="T_ce26e_level0_col3" class="col_heading level0 col3" >SleepTime</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Sex',
                          aggfunc=min)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_254b0_row0_col0, #T_254b0_row0_col1, #T_254b0_row0_col2, #T_254b0_row0_col3, #T_254b0_row1_col0, #T_254b0_row1_col1, #T_254b0_row1_col2, #T_254b0_row1_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_254b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_254b0_level0_col0" class="col_heading level0 col0" >BMI</th>
#       <th id="T_254b0_level0_col1" class="col_heading level0 col1" >MentalHealth</th>
#       <th id="T_254b0_level0_col2" class="col_heading level0 col2" >PhysicalHealth</th>
#       <th id="T_254b0_level0_col3" class="col_heading level0 col3" >SleepTime</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Race',
                          aggfunc=sum)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_4c725_row0_col0, #T_4c725_row0_col1, #T_4c725_row0_col2, #T_4c725_row0_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4c725_row1_col0 {
#   background-color: #19132d;
#   color: #f1f1f1;
# }
# #T_4c725_row1_col1 {
#   background-color: #1a1631;
#   color: #f1f1f1;
# }
# #T_4c725_row1_col2, #T_4c725_row1_col3 {
#   background-color: #19122b;
#   color: #f1f1f1;
# }
# #T_4c725_row2_col0, #T_4c725_row2_col1 {
#   background-color: #180f25;
#   color: #f1f1f1;
# }
# #T_4c725_row2_col2 {
#   background-color: #191129;
#   color: #f1f1f1;
# }
# #T_4c725_row2_col3 {
#   background-color: #160d21;
#   color: #f1f1f1;
# }
# #T_4c725_row3_col0 {
#   background-color: #0a030a;
#   color: #f1f1f1;
# }
# #T_4c725_row3_col1, #T_4c725_row3_col2 {
#   background-color: #0e050f;
#   color: #f1f1f1;
# }
# #T_4c725_row3_col3 {
#   background-color: #080308;
#   color: #f1f1f1;
# }
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Race',
                          aggfunc=max)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_efc9d_row0_col0, #T_efc9d_row0_col1, #T_efc9d_row0_col2, #T_efc9d_row1_col1, #T_efc9d_row1_col2, #T_efc9d_row1_col3, #T_efc9d_row2_col1, #T_efc9d_row2_col2, #T_efc9d_row3_col1, #T_efc9d_row3_col2, #T_efc9d_row4_col1, #T_efc9d_row4_col2, #T_efc9d_row5_col1, #T_efc9d_row5_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_efc9d_row0_col3, #T_efc9d_row2_col3, #T_efc9d_row3_col3, #T_efc9d_row4_col3, #T_efc9d_row5_col0, #T_efc9d_row5_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_efc9d_row1_col0 {
#   background-color: #1b1e3b;
#   color: #f1f1f1;
# }
# #T_efc9d_row2_col0 {
#   background-color: #c2d4f3;
#   color: #000000;
# }
# #T_efc9d_row3_col0 {
#   background-color: #4c792f;
#   color: #f1f1f1;
# }
# #T_efc9d_row4_col0 {
#   background-color: #dcf3ef;
#   color: #000000;
# }
# </style>
# <table id="T_efc9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='Race',
                          aggfunc=min)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_d7107_row0_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_d7107_row0_col1, #T_d7107_row0_col2, #T_d7107_row0_col3, #T_d7107_row1_col1, #T_d7107_row1_col2, #T_d7107_row1_col3, #T_d7107_row2_col0, #T_d7107_row2_col1, #T_d7107_row2_col2, #T_d7107_row2_col3, #T_d7107_row3_col1, #T_d7107_row3_col2, #T_d7107_row3_col3, #T_d7107_row4_col1, #T_d7107_row4_col2, #T_d7107_row4_col3, #T_d7107_row5_col0, #T_d7107_row5_col1, #T_d7107_row5_col2, #T_d7107_row5_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d7107_row1_col0 {
#   background-color: #c6e0f1;
#   color: #000000;
# }
# #T_d7107_row3_col0 {
#   background-color: #a4794c;
#   color: #f1f1f1;
# }
# #T_d7107_row4_col0 {
#   background-color: #d48ec3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d7107">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7107_level0_col0" class="col_heading level0 col0" >BMI</th>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='GenHealth',
                          aggfunc=sum)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_f121c_row0_col0 {
#   background-color: #16554b;
#   color: #f1f1f1;
# }
# #T_f121c_row0_col1 {
#   background-color: #9c7946;
#   color: #f1f1f1;
# }
# #T_f121c_row0_col2, #T_f121c_row1_col1, #T_f121c_row3_col0, #T_f121c_row3_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_f121c_row0_col3 {
#   background-color: #15464e;
#   color: #f1f1f1;
# }
# #T_f121c_row1_col0 {
#   background-color: #c6e0f1;
#   color: #000000;
# }
# #T_f121c_row1_col2 {
#   background-color: #cca6e4;
#   color: #000000;
# }
# #T_f121c_row1_col3 {
#   background-color: #c2c6f3;
#   color: #000000;
# }
# #T_f121c_row2_col0, #T_f121c_row2_col1, #T_f121c_row2_col3, #T_f121c_row4_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f121c_row2_col2 {
#   background-color: #d297d2;
#   color: #f1f1f1;
# }
# #T_f121c_row3_col1 {
#   background-color: #c2d2f3;
#   color: #000000;
# }
# #T_f121c_row3_col2 {
#   background-color: #236a3e;
#   color: #f1f1f1;
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='GenHealth',
                          aggfunc=max)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_2a728_row0_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_2a728_row0_col1, #T_2a728_row0_col2, #T_2a728_row0_col3, #T_2a728_row1_col1, #T_2a728_row1_col2, #T_2a728_row1_col3, #T_2a728_row2_col0, #T_2a728_row2_col1, #T_2a728_row2_col2, #T_2a728_row2_col3, #T_2a728_row3_col1, #T_2a728_row3_col2, #T_2a728_row3_col3, #T_2a728_row4_col1, #T_2a728_row4_col2, #T_2a728_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_2a728_row1_col0 {
#   background-color: #357435;
#   color: #f1f1f1;
# }
# #T_2a728_row3_col0 {
#   background-color: #d6f0ef;
#   color: #000000;
# }
# #T_2a728_row4_col0 {
#   background-color: #f6fcf8;
#   color: #000000;
# }
# </style>
# <table id="T_2a728">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a728_level0_col0" class="col_heading level0 col0" >BMI</th>
#       <th id="T_2a728_level0_col1" class="col_heading level0 col1" >MentalHealth</th>
# ...

# %%
segment_hs_code_description = pd.pivot_table(df, values=number_details, index='GenHealth',
                          aggfunc=min)

segment_hs_code_description = segment_hs_code_description.sort_values(by='PhysicalHealth', ascending=False)
segment_hs_code_description.style.background_gradient(cmap="cubehelix")
# Out:
# <style type="text/css">
# #T_db521_row0_col0 {
#   background-color: #154e4d;
#   color: #f1f1f1;
# }
# #T_db521_row0_col1, #T_db521_row0_col2, #T_db521_row0_col3, #T_db521_row1_col1, #T_db521_row1_col2, #T_db521_row1_col3, #T_db521_row2_col0, #T_db521_row2_col1, #T_db521_row2_col2, #T_db521_row2_col3, #T_db521_row3_col0, #T_db521_row3_col1, #T_db521_row3_col2, #T_db521_row3_col3, #T_db521_row4_col1, #T_db521_row4_col2, #T_db521_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_db521_row1_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_db521_row4_col0 {
#   background-color: #1f6741;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db521">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db521_level0_col0" class="col_heading level0 col0" >BMI</th>
#       <th id="T_db521_level0_col1" class="col_heading level0 col1" >MentalHealth</th>
# ...

# %%
plt.figure(figsize = [8, 3])

ax = sb.barplot(data = df, x = 'Sex', y = 'PhysicalHealth', hue = 'Race');
ax.legend(loc = 8, ncol = 3, framealpha = 1, title = 'Race');

# %%
plt.figure(figsize = [8, 3])

ax = sb.barplot(data = df, x = 'GenHealth', y = 'PhysicalHealth', hue = 'Sex');
ax.legend(loc = 8, ncol = 3, framealpha = 1, title = 'Sex');

# %%
plt.figure(figsize = [8, 2])

ct_counts = df.groupby(['GenHealth', 'Sex']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'GenHealth', columns = 'Sex', values = 'count')

sb.heatmap(ct_counts);

# %%
plt.figure(figsize = [8, 2])

ct_counts = df.groupby(['Race', 'Sex']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'Race', columns = 'Sex', values = 'count')

sb.heatmap(ct_counts);

# %%
sb.FacetGrid(df, hue='Race', height=4).map(plt.scatter, 'PhysicalHealth', 'MentalHealth').add_legend();

# %%
plt.figure(figsize = [8, 2])

sb.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0);

# %%
# create the plot
plt.figure(figsize = [8, 3]);

base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'GenHealth', color = base_color)

# add annotations
n_points = df.shape[0]
cat_counts = df['GenHealth'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    # print the annotation just below the top of the bar
    plt.text(loc, count-1, pct_string, ha = 'center', color = 'w')

# %%
# create the plot
plt.figure(figsize = [6, 2]);

base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'Sex', color = base_color)

# add annotations
n_points = df.shape[0]
cat_counts = df['Sex'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    # print the annotation just below the top of the bar
    plt.text(loc, count-1, pct_string, ha = 'center', color = 'w')

# %%
# create the plot
plt.figure(figsize = [15, 2]);

base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'Race', color = base_color)

# add annotations
n_points = df.shape[0]
cat_counts = df['Race'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    # print the annotation just below the top of the bar
    plt.text(loc, count-1, pct_string, ha = 'center', color = 'w')

# %%
# create the plot
plt.figure(figsize = [17, 2]);

base_color = sb.color_palette()[0]
sb.countplot(data = df, x = 'AgeCategory', color = base_color)

# add annotations
n_points = df.shape[0]
cat_counts = df['AgeCategory'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{:0.1f}%'.format(100*count/n_points)

    # print the annotation just below the top of the bar
    plt.text(loc, count-1, pct_string, ha = 'center', color = 'w')

# %%
# pre-processing: count and sort by the number of instances of each category
sorted_counts = df['Sex'].value_counts()

# establish the Figure
plt.figure(figsize = [25, 3])

# left plot: pie chart
plt.subplot(1, 2, 1)
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False);
plt.axis('square');

# right plot: horizontally stacked bar
plt.subplot(1, 2, 2)
baseline = 0
for i in range(sorted_counts.shape[0]):
    plt.barh(y = 1, width = sorted_counts[i], left = baseline)
    baseline += sorted_counts[i]

plt.legend(sorted_counts.index)  # add a legend for labeling
plt.ylim([0,2]); # give some vertical spacing around the bar

# %%
# pre-processing: count and sort by the number of instances of each category
sorted_counts = df['GenHealth'].value_counts()

# establish the Figure
plt.figure(figsize = [25, 3])

# left plot: pie chart
plt.subplot(1, 2, 1)
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False);
plt.axis('square');

# right plot: horizontally stacked bar
plt.subplot(1, 2, 2)
baseline = 0
for i in range(sorted_counts.shape[0]):
    plt.barh(y = 1, width = sorted_counts[i], left = baseline)
    baseline += sorted_counts[i]

plt.legend(sorted_counts.index)  # add a legend for labeling
plt.ylim([0,2]); # give some vertical spacing around the bar

# %%
plt.figure(figsize = [25, 5])
sb.boxplot(x='GenHealth', y='PhysicalHealth', hue="Sex", data=df);

# %%
plt.figure(figsize = [25, 5])
sb.boxplot(x='Sex', y='PhysicalHealth', hue='GenHealth', data=df);
